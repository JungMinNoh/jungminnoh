# %% [markdown]
# <a href="https://colab.research.google.com/github/JungMinNoh/jungminnoh/blob/master/%EC%95%A0%EB%8B%88%EB%A9%94%EC%9D%B4%EC%85%98_%EC%88%99%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML
from matplotlib import style

fig, ax=plt.subplots()
ax.set_xlim((-2,2))
ax.set_ylim((-1.1))
ax.set_xlabel("$x$", fontsize=12)
ax.set_ylabel("$y$", fontsize=12)
ax.grid(True)

line, =ax.plot([],[],lw=2)

def init():
  line.set_data([],[])
  return (line,)
  
def animate(t):
  x=np.linspace(-2,2,1000)
  y=np.sin(2*np.pi*x)*np.exp(-0.1*t)
  line.set_data(x,y)
  return (line,)

ani = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=50, blit=True)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
